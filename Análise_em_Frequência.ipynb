# %%
from sympy import *
from sympy.plotting import *
import sympy.physics.units as units

import numpy as np
import matplotlib.pyplot as plt

# %%
init_printing(pretty_print=true)

# %%
y = symbols('y')
x = symbols('x')
w = symbols('w')
k = symbols('k')
t = symbols('t')

j = sqrt(-1)
e = 2.71828

# %% [markdown]
# Abaixo, está a EDO apresentada no problema.

# %%
R = 3
L = 1
C = (1/2)

# %%
xt = (L*C)*(Derivative(Derivative(y ,t), t) + (R/L)*Derivative(y, t) + (1/L*C)*y)
xt
# Out:
#                            2
#              d            d
# 0.25⋅y + 1.5⋅──(y) + 0.5⋅───(y)
#              dt            2
#                          dt

# %% [markdown]
# ---

# %%
sinal = abs(sin(t))

# %%
plot(sinal)

# %%
a0 = (-2/pi)

# %%
ht = 2*((pow(e, -t) - pow(e, -2*t)))

# %%
plot(ht)

# %%
yt = ((2*sinal) * (ht))

# %%
yt
# Out:
#   ⎛         -t            -2⋅t⎞
# 2⋅⎝2⋅2.71828   - 2⋅2.71828    ⎠⋅│sin(t)│

# %%
plot(yt)
